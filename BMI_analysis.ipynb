# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
sns.set_theme(style="darkgrid")
import seaborn.objects as so
import seaborn as sns

# %%
data = pd.read_csv("weight-height-bmi.csv")

# %%
data
# Out:
#       Gender    Height      Weight         BMI
# 0       Male  1.875714  109.720985     Obesity
# 1       Male  1.747060   73.622732      Normal
# 2       Male  1.882397   96.497550  Overweight
# 3       Male  1.821967   99.809504     Obesity
# 4       Male  1.774998   93.598619  Overweight
# ...      ...       ...         ...         ...
# 9995  Female  1.680785   62.041159      Normal
# 9996  Female  1.703506   77.504315  Overweight
# 9997  Female  1.622247   58.275377      Normal
# 9998  Female  1.753470   74.322166      Normal
# 9999  Female  1.573384   51.550324      Normal
#
# [10000 rows x 4 columns]

# %%
data.head()
# Out:
#   Gender    Height      Weight         BMI
# 0   Male  1.875714  109.720985     Obesity
# 1   Male  1.747060   73.622732      Normal
# 2   Male  1.882397   96.497550  Overweight
# 3   Male  1.821967   99.809504     Obesity
# 4   Male  1.774998   93.598619  Overweight

# %%
data.describe().T
# Out:
#           count       mean        std        min        25%        50%  \
# Height  10000.0   1.685736   0.097727   1.378284   1.613043   1.684479
# Weight  10000.0  73.228054  14.564131  29.347460  61.605982  73.124894
#
#               75%         max
# Height   1.757026    2.006568
# Weight  84.898599  122.465167

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
#  3   BMI     10000 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 312.6+ KB

# %%
data.Gender.value_counts()
# Out:
# Male      5000
# Female    5000
# Name: Gender, dtype: int64

# %%
plt.figure(figsize = (18, 10))
(data.Gender.value_counts()).plot(kind='pie', autopct='%0.1f%%',startangle = 155)
plt.axis('equal')
plt.legend(title='Sexe', loc='upper left')
plt.title("Répartition en Fonction du Sexe", fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Répartition en Fonction du Sexe')

# %%
data.BMI.value_counts()
# Out:
# Overweight     5589
# Normal         4114
# Obesity         255
# Underweight      42
# Name: BMI, dtype: int64

# %%
plt.figure(figsize = (18, 10))
(data.BMI.value_counts()).plot(kind='pie', autopct='%0.1f%%',startangle = 140)
plt.axis('equal')
plt.legend(title='Critères', loc='upper left')
plt.title("Répartition des Critères du IMC", fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Répartition des Critères du IMC')

# %%
data.groupby('Gender')["BMI"].value_counts()
# Out:
# Gender  BMI
# Female  Normal         3887
#         Overweight     1071
#         Underweight      42
# Male    Overweight     4518
#         Obesity         255
#         Normal          227
# Name: BMI, dtype: int64

# %%
plt.figure(figsize = (18, 10))
(data.groupby('Gender')["BMI"].value_counts()).plot(kind='pie', autopct='%0.1f%%',startangle = 140)
plt.axis('equal')
plt.legend(title='Critère par Sexe', loc='upper left')
plt.title("Répartition des Critères du IMC en Fonction du Sexe", fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Répartition des Critères du IMC en Fonction du Sexe')

# %%
sns.pairplot(data)

# %%
data.head()
# Out:
#   Gender    Height      Weight         BMI
# 0   Male  1.875714  109.720985     Obesity
# 1   Male  1.747060   73.622732      Normal
# 2   Male  1.882397   96.497550  Overweight
# 3   Male  1.821967   99.809504     Obesity
# 4   Male  1.774998   93.598619  Overweight

# %%
data["BMI_Indice"] = data["Weight"]/(data["Height"]*data["Height"])

# %%
data.BMI_Indice
# Out:
# 0       31.185761
# 1       24.121044
# 2       27.232906
# 3       30.067059
# 4       29.708033
#           ...
# 9995    21.961166
# 9996    26.707835
# 9997    22.143748
# 9998    24.172512
# 9999    20.823898
# Name: BMI_Indice, Length: 10000, dtype: float64

# %%
data.head()
# Out:
#   Gender    Height      Weight         BMI  BMI_Indice
# 0   Male  1.875714  109.720985     Obesity   31.185761
# 1   Male  1.747060   73.622732      Normal   24.121044
# 2   Male  1.882397   96.497550  Overweight   27.232906
# 3   Male  1.821967   99.809504     Obesity   30.067059
# 4   Male  1.774998   93.598619  Overweight   29.708033

# %%
sns.pairplot(data, x_vars=['Height','Weight'], y_vars='BMI_Indice',size=5,aspect=1,kind='scatter')
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
